# %%
# !python -m pip install --upgrade pip

# %%
# !pip install pyodbc
# !pip install sqlalchemy

# %%
import pyodbc
import pandas as pd

# %%
# Replace with your actual details
server = r'RUCHI\SQLEXPRESS'  # e.g., 'localhost' or 'DESKTOP-12345\SQLEXPRESS'
database = 'Banking'
username = ''   # Leave blank if using Windows Authentication
password = ''   # Leave blank if using Windows Authentication

# Use Windows Authentication
conn = pyodbc.connect(
    f'DRIVER={{SQL Server}};SERVER={server};DATABASE={database};Trusted_Connection=yes;'
)

# %%
query = "SELECT TOP 5 * FROM customer"  # Replace with your table name
df = pd.read_sql(query, conn)
# Out:
# C:\Users\RUCHI SINGH\AppData\Local\Temp\ipykernel_80996\1089522850.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)

# %%
df.head()
# Out:
#   Client_ID             Name  Age  Location_ID Joined_Bank   Banking_Contact  \
# 0  IND81288    Raymond Mills   24        34324  2019-05-06    Anthony Torres
# 1  IND65833    Julia Spencer   23        42205  2001-12-10  Jonathan Hawkins
# 2  IND47499   Stephen Murray   27         7314  2010-01-25     Anthony Berry
# 3  IND72498   Virginia Garza   40        34594  2019-03-28        Steve Diaz
# 4  IND60181  Melissa Sanders   46        41269  2012-07-20        Shawn Long
#
#   Nationality            Occupation Fee_Structure Loyalty_Classification  ...  \
# 0    American  Safety Technician IV          High                   Jade  ...
# 1     African   Software Consultant          High                   Jade  ...
# 2    European    Help Desk Operator          High                   Gold  ...
# 3    American          Geologist II           Mid                 Silver  ...
# 4    American   Assistant Professor           Mid               Platinum  ...
#
# ...

# %%
df.describe()
# Out:
#              Age   Location_ID  Estimated_Income  Superannuation_Savings  \
# count   5.000000      5.000000          5.000000                5.000000
# mean   32.000000  31941.200000     204534.825000            26290.703809
# std    10.368221  14244.011959     115963.232033            18266.742239
# min    23.000000   7314.000000      75384.773438             5473.149902
# 25%    24.000000  34324.000000     130711.679688            17398.919922
# 50%    27.000000  34594.000000     169935.234375            17677.949219
# 75%    40.000000  41269.000000     289834.312500            42825.898438
# max    46.000000  42205.000000     356808.125000            48077.601562
#
#        Amount_of_Credit_Cards  Credit_Card_Balance    Bank_Loans  \
# count                5.000000             5.000000  5.000000e+00
# mean                 1.400000          3058.930023  8.538142e+05
# std                  0.547723          1686.933483  4.454937e+05
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Client_ID                 5 non-null      object
#  1   Name                      5 non-null      object
#  2   Age                       5 non-null      int64
#  3   Location_ID               5 non-null      int64
#  4   Joined_Bank               5 non-null      object
#  5   Banking_Contact           5 non-null      object
#  6   Nationality               5 non-null      object
#  7   Occupation                5 non-null      object
#  8   Fee_Structure             5 non-null      object
#  9   Loyalty_Classification    5 non-null      object
#  10  Estimated_Income          5 non-null      float64
#  11  Superannuation_Savings    5 non-null      float64
#  12  Amount_of_Credit_Cards    5 non-null      int64
# ...
