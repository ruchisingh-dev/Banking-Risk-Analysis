# %%
# !pip install seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("C:/Users/RUCHI SINGH/Documents/Data_analytics/Banking-Risk-Analysis/banking.csv")
df.head(5)
# Out:
#   Client ID             Name  Age  Location ID Joined Bank   Banking Contact  \
# 0  IND81288    Raymond Mills   24        34324  06-05-2019    Anthony Torres
# 1  IND65833    Julia Spencer   23        42205  10-12-2001  Jonathan Hawkins
# 2  IND47499   Stephen Murray   27         7314  25-01-2010     Anthony Berry
# 3  IND72498   Virginia Garza   40        34594  28-03-2019        Steve Diaz
# 4  IND60181  Melissa Sanders   46        41269  20-07-2012        Shawn Long
#
#   Nationality            Occupation Fee Structure Loyalty Classification  ...  \
# 0    American  Safety Technician IV          High                   Jade  ...
# 1     African   Software Consultant          High                   Jade  ...
# 2    European    Help Desk Operator          High                   Gold  ...
# 3    American          Geologist II           Mid                 Silver  ...
# 4    American   Assistant Professor           Mid               Platinum  ...
#
# ...

# %%
df.shape
# Out:
# (3000, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Client ID                 3000 non-null   object
#  1   Name                      3000 non-null   object
#  2   Age                       3000 non-null   int64
#  3   Location ID               3000 non-null   int64
#  4   Joined Bank               3000 non-null   object
#  5   Banking Contact           3000 non-null   object
#  6   Nationality               3000 non-null   object
#  7   Occupation                3000 non-null   object
#  8   Fee Structure             3000 non-null   object
#  9   Loyalty Classification    3000 non-null   object
#  10  Estimated Income          3000 non-null   float64
#  11  Superannuation Savings    3000 non-null   float64
#  12  Amount of Credit Cards    3000 non-null   int64
# ...

# %%
# Generate descriptive statistic for the data frames

df.describe()
# Out:
#                Age   Location ID  Estimated Income  Superannuation Savings  \
# count  3000.000000   3000.000000       3000.000000             3000.000000
# mean     51.039667  21563.323000     171305.034263            25531.599673
# std      19.854760  12462.273017     111935.808209            16259.950770
# min      17.000000     12.000000      15919.480000             1482.030000
# 25%      34.000000  10803.500000      82906.595000            12513.775000
# 50%      51.000000  21129.500000     142313.480000            22357.355000
# 75%      69.000000  32054.500000     242290.305000            35464.740000
# max      85.000000  43369.000000     522330.260000            75963.900000
#
#        Amount of Credit Cards  Credit Card Balance    Bank Loans  \
# count             3000.000000          3000.000000  3.000000e+03
# mean                 1.463667          3176.206943  5.913862e+05
# std                  0.676387          2497.094709  4.575570e+05
# ...

# %%
df["Estimated Income"]
# Out:
# 0        75384.77
# 1       289834.31
# 2       169935.23
# 3       356808.11
# 4       130711.68
#           ...
# 2995    297617.14
# 2996     42397.46
# 2997     48339.88
# 2998    107265.87
# 2999     56826.53
# Name: Estimated Income, Length: 3000, dtype: float64

# %%
# Define income band boundaries
# Converting Estimated Income into catagorical data
bins = [0, 100000, 300000, float('inf')]
labels = ['low', 'mid', 'High']

df['Income Band'] = pd.cut(df['Estimated Income'], bins=bins , labels=labels, right=False)

# %%
df['Income Band'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Income Band'>

# %%
# Examine the distribution of unique catagoried in categorical col
categorical_cols = df[["Amount of Credit Cards","Nationality","Fee Structure","Loyalty Classification","Properties Owned","Risk Weighting","Occupation","Income Band", "BRId", "IAId"]].columns

for col in categorical_cols:
    print(f"Value count for '{col}':")
    display(df[col].value_counts())
# Out:
# Value count for 'Amount of Credit Cards':
# Amount of Credit Cards
# 1    1922
# 2     765
# 3     313
# Name: count, dtype: int64
# Value count for 'Nationality':
# Nationality
# European      1309
# Asian          754
# American       507
# Australian     254
# African        176
# Name: count, dtype: int64
# Value count for 'Fee Structure':
# Fee Structure
# High    1476
# Mid      962
# Low      562
# Name: count, dtype: int64
# Value count for 'Loyalty Classification':
# Loyalty Classification
# Jade        1331
# Silver       767
# Gold         585
# Platinum     317
# Name: count, dtype: int64
# Value count for 'Properties Owned':
# Properties Owned
# 2    777
# 1    776
# 3    742
# 0    705
# Name: count, dtype: int64
# Value count for 'Risk Weighting':
# Risk Weighting
# 2    1222
# 1     836
# 3     460
# 4     322
# 5     160
# Name: count, dtype: int64
# Value count for 'Occupation':
# Occupation
# Associate Professor             28
# Structural Analysis Engineer    28
# ...

# %% [markdown]
# ## Univariate analysis

# %%
# ploting the distribution of unique catagoried in categorical col

for i, col in enumerate(categorical_cols, start=1):
    
    # --- special case: only top‑5 occupations ---
    if col == "Occupation":
        top_vals = df[col].value_counts().nlargest(10).index          # top 5 labels
        data     = df[df[col].isin(top_vals)]                         # keep only those rows
        order    = top_vals                                           # bar order
        title    = f"Top 10 {col}s"
    else:
        data     = df                                                 # full data
        order    = df[col].value_counts().index                       # all labels, most‑common first
        title    = f"Distribution of {col}"
    
    # --- plotting ---
    plt.figure(i, figsize=(6, 4))
    sns.countplot(data=data, x=col, order=order)
    plt.title(title)
    plt.xticks(rotation=45, ha="right")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Bivariate analysis

# %%
# Create subplot grid — adjust rows/cols as needed
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(15, 18))
axes = axes.flatten()  # make it easier to loop

for i, col in enumerate(categorical_cols):
    
    ax = axes[i]
    
    # Special handling for Occupation (Top 10)
    if col == "Occupation":
        top_vals = df[col].value_counts().nlargest(10).index
        data     = df[df[col].isin(top_vals)]
        order    = top_vals
        title    = f"Top 10 {col}s"
    else:
        data     = df
        order    = df[col].value_counts().index
        title    = f"{col}"
    
    sns.countplot(data=data, x=col, order=order, hue="Nationality", ax=ax)
    ax.set_title(title)
    ax.tick_params(axis='x', rotation=45)

# Turn off any unused subplot spaces
for j in range(len(categorical_cols), len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[24], line 7
#       3 axes = axes.flatten()  # make it easier to loop
#       5 for i, col in enumerate(categorical_cols):
# ----> 7     ax = axes[i]
#       9     # Special handling for Occupation (Top 10)
#      10     if col == "Occupation":
#
# IndexError: index 8 is out of bounds for axis 0 with size 8

# %%
# Histplot of value count for diffrent occupation
# NOT RIGHT SAME THING DONE ABOVE
for col in categorical_cols:
    if col == "Occupation":
        continue
    plt.figure(figsize=(8,4))
    sns.histplot(df[col])
    plt.title(f"Histogram of {col} Count")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# ## Numerical Analysis

# %%
numerical_cols = ['Fee Structure', 'Age','Estimated Income', 'Superannuation Savings', 'Credit Card Balance', 'Bank Loans', 'Bank Deposits', 'Checking Accounts', 'Saving Accounts', 'Foreign Currency Account', 'Business Lending']

# Univariate analysis and visualisation
plt.figure(figsize=(15, 10))
for i,col in enumerate(numerical_cols):
    plt.subplot(4,3,i+1)
    sns.histplot(df[col],kde=True)
    plt.title(col)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Heatmaps

# %%
numerical_cols = ['Age', 'Estimated Income', 'Superannuation Savings', 'Credit Card Balance',
                  'Bank Loans', 'Bank Deposits', 'Checking Accounts', 'Saving Accounts',
                  'Foreign Currency Account', 'Business Lending', 'Properties Owned']
correlation_matrix = df[numerical_cols].corr()

plt.figure(figsize=(8,8))
sns.heatmap(correlation_matrix, annot=True, cmap='crest', fmt=".2f")
plt.title('Correlation Matrix of Numerical Features')
plt.show()
